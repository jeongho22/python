# %%
import sys
import tensorflow as tf

print(sys.version)
print(tf.__version__)
# Out:
# 3.7.11 (default, Jul 27 2021, 09:42:29) [MSC v.1916 64 bit (AMD64)]
# 1.15.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action="ignore")

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl
mpl.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 1. 텐서
#
# + OD tensor,1D tensor,2D tensor,3D tensor,고차원 tensor
# + 딥러닝에서는 0D~ 4D(이미지)까지 주로 사용한다.
# + 동영상을 다룰 때에는 5D텐서까지 사용

# %% [markdown]
# ## 2. 기본 구성 요소
#
# + placeholder()
# + constant
# + Variable()

# %% [markdown]
# #### (1) constant
#
# + 절대 변하지 않는 상수
# + 자체적으로 그래프를 갖는다.
# + 메서드
# + tf.constant(value,dtype=None,shape=None,name='Const',verify_shape=False)

# %%
a = tf.constant(10)
print(a)

b = tf.constant(20)
print(b)

c = tf.add(a,b)
print(c)
# Out:
# Tensor("Const_29:0", shape=(), dtype=int32)
# Tensor("Const_30:0", shape=(), dtype=int32)
# Tensor("Add_13:0", shape=(), dtype=int32)

# %%
sess = tf.Session()
#print(sess.run(a))
#print(sess.run(b))
print(sess.run(c))
# Out:
# 30

# %%
### Tensorborad
# tensorboard -- logdir=log_dir
# http://localhost:6006

tf.summary.FileWriter("log_dir",graph=sess.graph) # 현재위치에 이 폴더가 만들어짐 그래프를 저장하여라 sess
# Out:
# WARNING:tensorflow:From C:\Users\김정호\AppData\Local\Temp/ipykernel_5360/3092554864.py:3: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.

# %%
sess.close()

# %%
##### (5+2)*3

a = tf.constant(5)
b = tf.constant(2)
c = tf.add(a, b)
d = tf.constant(5)
e = tf.multiply(c, d)

# %%
sess = tf.Session()
print(sess.run(e))
# Out:
# 35

# %%
tf.summary.FileWriter("log_dir",graph=sess.graph) #많이안쓰임

# %%
sees.close()

# %% [markdown]
# ## (2)Variable
#
# + 객체로 정의되어 있다.
# + weight(가중치)를 저장하는 변수
# + 사용전에 반드시 초기화를 해야한다.(global_variables_initializer()호출)

# %%
v1 = tf.Variable(initial_value=5)
v2 = tf.Variable(initial_value=3)
v3 = tf.Variable(initial_value=2)

v4 = v1+v2+v3

print(v4)
# Out:
# Tensor("add_18:0", shape=(), dtype=int32)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print(sess.run(v4))
# Out:
# 10

# %%
tf.summary.FileWriter("log_dir",graph=sess.graph)

# %%
sess.close()

# %% [markdown]
# ### (3) placeholder
#
# + 그래프를 만들지 않는다
# + 입력된 데이터를 텐서와 매핑하는 역할

# %%
v1 = tf.placeholder(dtype=tf.float32)
v2 = tf.placeholder(dtype=tf.float32)
v3 = tf.placeholder(dtype=tf.float32)

v4 = v1+v2+v3

print(v4)
# Out:
# Tensor("add_20:0", dtype=float32)

# %%
a, b, c = 5,3,4

sess = tf.Session()
sess.run(v4, feed_dict={v1:a,v2:b,v3:c})
# Out:
# 12.0

# %%
sess.close()

# %%
#### 구구단 프로그램 

def gugudan(dan):
    left = tf.placeholder(tf.int32)
    right = tf.placeholder(tf.int32)
    op = tf.multiply(left,right)
    
    sess = tf.Session()
    for i in range(1,10):
        result = sess.run(op, feed_dict={left:dan, right:i})
        print("{}*{}={}".format(dan,i,result))
        
    sess.close()

# %%
gugudan(3)
# Out:
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
