# %%
import tensorflow as tf

# %%
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.7.0
# 2.7.0

# %% [markdown]
# ## 1. 특징
#
# + keras와 즉시 실행(eager execution) 을 이용한 쉬운 모델 작성
# + 어떤 플랫폼에서든 튼튼한 (robust)모델을 배포
# + 연구를 위한 강력한 실험법
# + deprecated된 API 를 정리하고 중복을 줄여서 API를 단순화
#
# ## 2.API
#
# + tf.data
# + tf.keras

# %%
t1=tf.constant(10)
print(t1)
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
t2 =t1+ 5
print(t2)

print(t2.numpy())
# Out:
# tf.Tensor(15, shape=(), dtype=int32)
# 15

# %%
#### 데이터 준비


x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random_normal([1]),dtype=tf.float32)
b = tf.Variable(tf.random_normal([1]),dtype=tf.float32)

# 정답은 1인걸 이미 알고있긴함...
#### 가설 준비(y = Wx+b)

hypot = W * x_train +b


#### 비용함수 (비용을 구하는 공식) w

cost = tf.reduce_mean(tf.square(hypot-y_train)) # y_train 오차값 뺀다




# 그래프가 w의 값 비용을 그려보니 볼록한... convex그래프라고함 경사하강법
# 이제 최저비용을 찾는게 목표 30일때....최저임... 찾아보자 ! 2.경사하강 알고리즘으로


gradient = tf.reduce_mean((hypot-y_train) * x_train)
learning_rate = 0.01 # 훈련 횟수도 잘맞아떨어짐 작게잡으면,크게하면 최저비용의 위치를 건너뜀
descent = W - (learning_rate * gradient)
update = W.assign(descent)


###### --------------------------그래프 완성-----------------------###### 


sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(50):
    _, weight, c = sess.run([update, W, cost])
    print(step, weight, c)

    
sess.close()

# %%
x_train = [1,2,3]
y_train = [1,2,3]

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(1,input_shape=(1,)))
model.compile(loss="mse",optimizer=tf.keras.optimizers.SGD(lr=0.01))
model.fit(x_train,y_train, epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 553ms/step - loss: 2.3289
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8429
# Epoch 3/50
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4587
# Epoch 4/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1550
# Epoch 5/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9149
# Epoch 6/50
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7251
# Epoch 7/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5751
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4565
# Epoch 9/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3628
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2887
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2301
# Epoch 12/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1838
# Epoch 13/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1472
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1182
# Epoch 15/50
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0953
# Epoch 16/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0772
# Epoch 17/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0629
# Epoch 18/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0515
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0426
# Epoch 20/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0355
# Epoch 21/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0299
# Epoch 22/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0254
# Epoch 23/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0219
# Epoch 24/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0191
# Epoch 25/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0169
# Epoch 26/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0151
# Epoch 27/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0137
# Epoch 28/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0126
# Epoch 29/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0117
# Epoch 30/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0110
# Epoch 31/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0104
# Epoch 32/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0100
# Epoch 33/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 34/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0093
# Epoch 35/50
# 1/1 [==============================] - ETA: 0s - loss: 0.009 - 0s 13ms/step - loss: 0.0090
# Epoch 36/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0088
# Epoch 37/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0087
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0085
# Epoch 39/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0084
# Epoch 40/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0083
# Epoch 41/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 42/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0081
# Epoch 44/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 45/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0079
# Epoch 46/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 49/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0077
# Epoch 50/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0077
